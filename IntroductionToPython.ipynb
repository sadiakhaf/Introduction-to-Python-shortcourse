# %% [markdown]
# <a href="https://colab.research.google.com/github/sadiakhaf/Introduction-to-Python-shortcourse/blob/main/IntroductionToPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Python - Basic Concepts 😄
# This Notebook will serve as the master Notebook as we progress through this class. Feel free to copy this into your own notebook for practice and make modifications.😃
# We will start with three important concepts and build on them.
# 1. Variables
# 2. Conditionals
# 3. Loops

# %%
# A comment is a line of code that explains to the reader what the code does. 
# Comments can be used to leave helpful hints about the code for yourself to 
# read later, and for others to understand your code and reuse it.

print("Let's start some real coding today!") #This line prints a statement
person = "Vincent" #The data type of variable here is??

#How can we find the data type of a variable we just created?
# Out:
# Let's start some real coding today!

# %%
type(person)
# Out:
# str

# %%
device = "IPad"
model = 2021
cost = 400
specifications =("White","Black","Midnight Blue","Another invented obscure color name") #Can you update/edit this
other_specifications = ["Home button","No Home button","Works with Apple pencil 2"] #Can you update/edit this
print("The cost of device {d}, model {m}, is {c}".format(d=device,c=cost, m=model)) #Pay attention to the order of variables here
# Out:
# The cost of device IPad, model 2021, is 400

# %% [markdown]
# # What Data Types Does your project Need? 🤔
#
# ![image.png](data:image/png;base64,...)
#
# # What arithmatic operations does your project need?
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Conditionals If ElseIF Else
# Remember the branches of a code?
#
# ![image.png](data:image/png;base64,...)
# #Loops
# Remember the getting stuck inside the infinite loop?
#
# ![image.png](data:image/png;base64,...)

# %%
a = 200
b = 33
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
else:
  print("a is greater than b")

# %%
for item in specifications:
  print(item)
# Out:
# White
# Black
# Midnight Blue
# Another invented obscure color name

# %%
for item in other_specifications:
  print("Other specification is " + item)
# Out:
# Other specification is Home button
# Other specification is No Home button
# Other specification is Works with Apple pencil 2

# %%
for item in range(11):
  print("The value stored in item right now is {}".format(item))
# Out:
# The value stored in item right now is 0
# The value stored in item right now is 1
# The value stored in item right now is 2
# The value stored in item right now is 3
# The value stored in item right now is 4
# The value stored in item right now is 5
# The value stored in item right now is 6
# The value stored in item right now is 7
# The value stored in item right now is 8
# The value stored in item right now is 9
# The value stored in item right now is 10

# %% [markdown]
# # 🏋️‍♀️Exercise 1 Even/Odd Numbers
# Write a code that gives you the following output. Use any and all concepts learned so far!
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Solution ⚠
#
# Don't look before trying it yourself.

# %%
for item in range(11):
  if item % 2 == 0:
    print("The number "+ str(item) +" is an EVEN number")
  else:
    print("The number "+ str(item) +" is an ODD number")
# Out:
# The number 0 is an EVEN number
# The number 1 is an ODD number
# The number 2 is an EVEN number
# The number 3 is an ODD number
# The number 4 is an EVEN number
# The number 5 is an ODD number
# The number 6 is an EVEN number
# The number 7 is an ODD number
# The number 8 is an EVEN number
# The number 9 is an ODD number
# The number 10 is an EVEN number

# %% [markdown]
# # For Creating games with random numbers, die rolls
# All the variables we learnt so far don't let us create games with dice roll etc.
# To create coin flip or dice roll, we need help.
# Let's say you are working on creating a "digital" Dungeons-And-Dragons or Ludo.
#
#
# ![image.png](data:image/png;base64,...)
#
# The right question to google "How to create

# %% [markdown]
# # What really is the right question to ask here? 💁‍♀️
# How to create Ludo in python?
#
# *   How to create games in python?
# *   What's missing from our computations?
# *   How to get user input in python?
# *   How to creat a button in python?
# *   How to generate a random number in python?

# %%
from random import randrange
print(randrange(7))
# Out:
# 0

# %% [markdown]
# # What's the problem, and how can we fix it? ✋✋
# ## Take Home Assignment
#
#
# *   Create a multi player game, each player rolls a die 10 times.
# *   The player with most "ODD" number die rolls wins.
# *   In case of a tie, roll again untill we have a winner.
#
# Tip: Use the following resources if needed for player names or anything else.
# https://colab.research.google.com/github/rajeshkumarkarra/Learn_Python/blob/updates/Input_or_Output.ipynb#scrollTo=P9AmKmQAbtna
